# %% [markdown]
# ##
# ### Prueba 2 Proyecto Bioinformática
# Brenda Calderón

# %% [markdown]
# Creé carpeta **data100** dentro de `/home/brenda/Escritorio/Bren_bioinf/Proy_Intento1/data` y moví los archivos 100*.fastq (secuencias de 100,000 por individuo) a **data100**. Dentro de la carpeta empecé un nuevo **Assembly** en ipyrad

# %%
# iniciar miniconda2
export PATH="/home/brenda/miniconda2/bin/:$PATH"

# %%
# Crear un nuevo Assembly
ipyrad -n test100

# %%
New file 'params-test100.txt' created in /home/brenda/Escritorio/Bren_bioinf/Proy_Intento1/data/data100

# %%
# Modificar los parámetros
# project_dir = ./data"
# sorted_fastq_path = ./data/*.fastq
# datatype = gbs
# filter_min_trim_len = 50
# filter_adapters = 2
# max_SNPs_locus = (10, 10)
# output_formats = p, k, v
nano params-test100.txt

# %%
# Empezar el análisis
# Step 1 Demultiplexing (sorted among individuals/samples )/ Loading fastq files
# Mis muestras ya están demultiplexadas (-.-), sólo las carga.
ipyrad -p params-test100.txt -s 1

# %%
 -------------------------------------------------------------
  ipyrad [v.0.7.23]
  Interactive assembly and analysis of RAD-seq data
 -------------------------------------------------------------
  loading Assembly: test100
  from saved path: ~/Escritorio/Bren_bioinf/Proy_Intento1/data/data100/test100.json
  New Assembly: test100
  establishing parallel connection:
  host compute node: [4 cores] on b-aspire-f5

  Step 1: Loading sorted fastq data to Samples
  [####################] 100%  loading reads         | 0:00:01  
  26 fastq files loaded to 26 Samples.

# %%
# Resumen de los resultados del paso 1
ipyrad -p params-test100.txt -r

# %%
Summary stats of Assembly test100
------------------------------------------------
                   state  reads_raw
100_ATX_1_S237001      1     100000
100_ATX_2_S155001      1     100000
100_ATX_3_S167001      1     100000
100_ATX_4_S179001      1     100000
100_ATX_5_S190001      1     100000
100_ATX_6_S202001      1     100000
100_ATX_7_S214001      1     100000
100_ATX_8_S226001      1     100000
100_ATX_9_S238001      1     100000
100_PRE_1_S152001      1     100000
100_PRE_2_S164001      1     100000
100_PRE_3_S176001      1     100000
100_PRE_5_S199001      1     100000
100_PRE_6_S211001      1     100000
100_PRE_7_S223001      1     100000
100_PRE_8_S235001      1     100000
100_PRE_9_S153001      1     100000
100_QUE_1_S228001      1     100000
100_QUE_2_S240001      1     100000
100_QUE_3_S158001      1     100000
100_QUE_4_S170001      1     100000
100_QUE_5_S182001      1     100000
100_QUE_6_S193001      1     100000
100_QUE_7_S205001      1     100000
100_QUE_8_S217001      1     100000
100_QUE_9_S229001      1     100000


Full stats files
------------------------------------------------
step 1: ./test100_s1_demultiplex_stats.txt
step 2: None
step 3: None
step 4: None
step 5: None
step 6: None
step 7: None

# %%
# Correr paso 2
# Filtering  / Editing reads (quality score recorded in the fastQ data files to filter low quality base calls.)
ipyrad -p params-test100.txt -s 2

# %%
 -------------------------------------------------------------
  ipyrad [v.0.7.23]
  Interactive assembly and analysis of RAD-seq data
 -------------------------------------------------------------
  loading Assembly: test100
  from saved path: ~/Escritorio/Bren_bioinf/Proy_Intento1/data/data100/test100.json
  establishing parallel connection:
  host compute node: [4 cores] on b-aspire-f5

  Step 2: Filtering reads 
  [####################] 100%  processing reads      | 0:00:54

# %%
# Resumen de los resultados del paso 2
ipyrad -p params-test100.txt -r

# %% [markdown]
# Aproximadamente 500 secuencias por individuo no cumplían con los estándares de calidad y fueron removidas.
# Los parámetros que modifiqué (los otros se quedaron como vienen en el programa) fueron:
#
# filter_min_trim_len = 50  ->  minimum trimmed seqlen of 50 (se queda con secuecnias de losngitud mínima de 50)
#
# filter_adapters = 2  ->  strict filter for adapters

# %%
Summary stats of Assembly test100
------------------------------------------------
                   state  reads_raw  reads_passed_filter
100_ATX_1_S237001      2     100000                99515
100_ATX_2_S155001      2     100000                99514
100_ATX_3_S167001      2     100000                99503
100_ATX_4_S179001      2     100000                99518
100_ATX_5_S190001      2     100000                99535
100_ATX_6_S202001      2     100000                99484
100_ATX_7_S214001      2     100000                99493
100_ATX_8_S226001      2     100000                99563
100_ATX_9_S238001      2     100000                99527
100_PRE_1_S152001      2     100000                99628
100_PRE_2_S164001      2     100000                99506
100_PRE_3_S176001      2     100000                99514
100_PRE_5_S199001      2     100000                99612
100_PRE_6_S211001      2     100000                99638
100_PRE_7_S223001      2     100000                99486
100_PRE_8_S235001      2     100000                99344
100_PRE_9_S153001      2     100000                99602
100_QUE_1_S228001      2     100000                99517
100_QUE_2_S240001      2     100000                99592
100_QUE_3_S158001      2     100000                99570
100_QUE_4_S170001      2     100000                99533
100_QUE_5_S182001      2     100000                99476
100_QUE_6_S193001      2     100000                99493
100_QUE_7_S205001      2     100000                99487
100_QUE_8_S217001      2     100000                99532
100_QUE_9_S229001      2     100000                99542


Full stats files
------------------------------------------------
step 1: ./test100_s1_demultiplex_stats.txt
step 2: ./test100_edits/s2_rawedit_stats.txt
step 3: None
step 4: None
step 5: None
step 6: None
step 7: None

# %%
# Correr paso 3
# Clustering / Mapping reads within Samples and alignment
# (reads are matched together on the basis of sequence similarity and the resulting clusters are aligned)
ipyrad -p params-test100.txt -s 3

# %% [markdown]
# Para este paso se puede modificar el parámetro
# `clust_threshold` el cual, es the level of sequence similarity at which two sequences are identified as being homologous, and thus cluster together.
# lo dejé como viene en el programa: `[14] clust threshold set to 85% -> 0.85`

# %%
 -------------------------------------------------------------
  ipyrad [v.0.7.23]
  Interactive assembly and analysis of RAD-seq data
 -------------------------------------------------------------
  loading Assembly: test100
  from saved path: ~/Escritorio/Bren_bioinf/Proy_Intento1/data/data100/test100.json
  establishing parallel connection:
  host compute node: [4 cores] on b-aspire-f5

  Step 3: Clustering/Mapping reads
  [####################] 100%  dereplicating         | 0:00:05  
  [####################] 100%  clustering            | 0:20:00  
  [####################] 100%  building clusters     | 0:00:05  
  [####################] 100%  chunking              | 0:00:00  
  [####################] 100%  aligning              | 0:42:04  
  [####################] 100%  concatenating         | 0:00:04

# %%
# Resumen de los resultados del paso 3
ipyrad -p params-test100.txt -r

# %%
Summary stats of Assembly test100
------------------------------------------------
                   state  reads_raw  reads_passed_filter  clusters_total  \
100_ATX_1_S237001      3     100000                99515           38670   
100_ATX_2_S155001      3     100000                99514           39236   
100_ATX_3_S167001      3     100000                99503           39201   
100_ATX_4_S179001      3     100000                99518           39665   
100_ATX_5_S190001      3     100000                99535           39145   
100_ATX_6_S202001      3     100000                99484           39914   
100_ATX_7_S214001      3     100000                99493           38299   
100_ATX_8_S226001      3     100000                99563           38374   
100_ATX_9_S238001      3     100000                99527           39023   
100_PRE_1_S152001      3     100000                99628           31504   
100_PRE_2_S164001      3     100000                99506           39055   
100_PRE_3_S176001      3     100000                99514           38457   
100_PRE_5_S199001      3     100000                99612           24574   
100_PRE_6_S211001      3     100000                99638           25751   
100_PRE_7_S223001      3     100000                99486           37787   
100_PRE_8_S235001      3     100000                99344           25164   
100_PRE_9_S153001      3     100000                99602           25367   
100_QUE_1_S228001      3     100000                99517           37568   
100_QUE_2_S240001      3     100000                99592           39125   
100_QUE_3_S158001      3     100000                99570           38236   
100_QUE_4_S170001      3     100000                99533           38286   
100_QUE_5_S182001      3     100000                99476           38511   
100_QUE_6_S193001      3     100000                99493           38445   
100_QUE_7_S205001      3     100000                99487           38480   
100_QUE_8_S217001      3     100000                99532           38648   
100_QUE_9_S229001      3     100000                99542           37928   

                   clusters_hidepth  
100_ATX_1_S237001               992  
100_ATX_2_S155001              1036  
100_ATX_3_S167001               957  
100_ATX_4_S179001              1062  
100_ATX_5_S190001               989  
100_ATX_6_S202001              1036  
100_ATX_7_S214001              1018  
100_ATX_8_S226001              1274  
100_ATX_9_S238001               970  
100_PRE_1_S152001              1483  
100_PRE_2_S164001               978  
100_PRE_3_S176001               964  
100_PRE_5_S199001              1410  
100_PRE_6_S211001              1452  
100_PRE_7_S223001              1022  
100_PRE_8_S235001              1478  
100_PRE_9_S153001              1442  
100_QUE_1_S228001              1016  
100_QUE_2_S240001              1008  
100_QUE_3_S158001              1023  
100_QUE_4_S170001              1000  
100_QUE_5_S182001              1074  
100_QUE_6_S193001              1032  
100_QUE_7_S205001               984  
100_QUE_8_S217001              1016  
100_QUE_9_S229001               951  


Full stats files
------------------------------------------------
step 1: ./test100_s1_demultiplex_stats.txt
step 2: ./test100_edits/s2_rawedit_stats.txt
step 3: ./test100_clust_0.85/s3_cluster_stats.txt
step 4: None
step 5: None
step 6: None
step 7: None

# %%
# Correr paso 4
# Joint estimation of heterozygosity and error rate
ipyrad -p params-test100.txt -s 4

# %%
 -------------------------------------------------------------
  ipyrad [v.0.7.23]
  Interactive assembly and analysis of RAD-seq data
 -------------------------------------------------------------
  loading Assembly: test100
  from saved path: ~/Escritorio/Bren_bioinf/Proy_Intento1/data/data100/test100.json
  establishing parallel connection:
  host compute node: [4 cores] on b-aspire-f5

  Step 4: Joint estimation of error rate and heterozygosity
  [####################] 100%  inferring [H, E]      | 0:00:37

# %%
# Resumen de los resultados del paso 4
ipyrad -p params-test100.txt -r

# %%
Summary stats of Assembly test100
------------------------------------------------
ipyrad -p params-test100.txt -s 5

# %%
 -------------------------------------------------------------
  ipyrad [v.0.7.23]
  Interactive assembly and analysis of RAD-seq data
 -------------------------------------------------------------
  loading Assembly: test100
  from saved path: ~/Escritorio/Bren_bioinf/Proy_Intento1/data/data100/test100.json
  establishing parallel connection:
  host compute node: [4 cores] on b-aspire-f5

  Step 5: Consensus base calling 
  Mean error  [0.01253 sd=0.00316]
  Mean hetero [0.03130 sd=0.00579]
  [####################] 100%  calculating depths    | 0:00:06  
  [####################] 100%  chunking clusters     | 0:00:05  
  [####################] 100%  consens calling       | 0:01:50

# %%
# Resumen de los resultados del paso 5
ipyrad -p params-test100.txt -r

# %%
Summary stats of Assembly test100
------------------------------------------------
                   state  reads_raw  reads_passed_filter  clusters_total  \
100_ATX_1_S237001      5     100000                99515           38670   
100_ATX_2_S155001      5     100000                99514           39236   
100_ATX_3_S167001      5     100000                99503           39201   
100_ATX_4_S179001      5     100000                99518           39665   
100_ATX_5_S190001      5     100000                99535           39145   
100_ATX_6_S202001      5     100000                99484           39914   
100_ATX_7_S214001      5     100000                99493           38299   
100_ATX_8_S226001      5     100000                99563           38374   
100_ATX_9_S238001      5     100000                99527           39023   
100_PRE_1_S152001      5     100000                99628           31504   
100_PRE_2_S164001      5     100000                99506           39055   
100_PRE_3_S176001      5     100000                99514           38457   
100_PRE_5_S199001      5     100000                99612           24574   
100_PRE_6_S211001      5     100000                99638           25751   
100_PRE_7_S223001      5     100000                99486           37787   
100_PRE_8_S235001      5     100000                99344           25164   
100_PRE_9_S153001      5     100000                99602           25367   
100_QUE_1_S228001      5     100000                99517           37568   
100_QUE_2_S240001      5     100000                99592           39125   
100_QUE_3_S158001      5     100000                99570           38236   
100_QUE_4_S170001      5     100000                99533           38286   
100_QUE_5_S182001      5     100000                99476           38511   
100_QUE_6_S193001      5     100000                99493           38445   
100_QUE_7_S205001      5     100000                99487           38480   
100_QUE_8_S217001      5     100000                99532           38648   
100_QUE_9_S229001      5     100000                99542           37928   

                   clusters_hidepth  hetero_est  error_est  reads_consens  
100_ATX_1_S237001               992    0.032624   0.014288            489  
100_ATX_2_S155001              1036    0.031200   0.014542            546  
100_ATX_3_S167001               957    0.034570   0.012894            473  
100_ATX_4_S179001              1062    0.031465   0.013548            586  
100_ATX_5_S190001               989    0.035458   0.015471            474  
100_ATX_6_S202001              1036    0.031258   0.014061            560  
100_ATX_7_S214001              1018    0.034722   0.014058            489  
100_ATX_8_S226001              1274    0.025144   0.011142            805  
100_ATX_9_S238001               970    0.035310   0.013636            459  
100_PRE_1_S152001              1483    0.022728   0.006983           1069  
100_PRE_2_S164001               978    0.033174   0.014663            482  
100_PRE_3_S176001               964    0.033605   0.014555            479  
100_PRE_5_S199001              1410    0.020188   0.005705           1052  
100_PRE_6_S211001              1452    0.021020   0.007457           1071  
100_PRE_7_S223001              1022    0.035278   0.014910            489  
100_PRE_8_S235001              1478    0.019386   0.006110           1129  
100_PRE_9_S153001              1442    0.020811   0.005874           1107  
100_QUE_1_S228001              1016    0.037283   0.013706            510  
100_QUE_2_S240001              1008    0.033238   0.014962            501  
100_QUE_3_S158001              1023    0.034100   0.013835            524  
100_QUE_4_S170001              1000    0.034096   0.013755            500  
100_QUE_5_S182001              1074    0.033236   0.013355            555  
100_QUE_6_S193001              1032    0.033028   0.013900            536  
100_QUE_7_S205001               984    0.037636   0.013852            465  
100_QUE_8_S217001              1016    0.035304   0.014896            497  
100_QUE_9_S229001               951    0.038032   0.013541            459  


Full stats files
------------------------------------------------
step 1: ./test100_s1_demultiplex_stats.txt
step 2: ./test100_edits/s2_rawedit_stats.txt
step 3: ./test100_clust_0.85/s3_cluster_stats.txt
step 4: ./test100_clust_0.85/s4_joint_estimate.txt
step 5: ./test100_consens/s5_consens_stats.txt
step 6: None
step 7: None

# %%
# Correr paso 6
#  Clustering / Mapping reads among Samples and alignment
ipyrad -p params-test100.txt -s 6

# %%
 -------------------------------------------------------------
  ipyrad [v.0.7.23]
  Interactive assembly and analysis of RAD-seq data
 -------------------------------------------------------------
  loading Assembly: test100
  from saved path: ~/Escritorio/Bren_bioinf/Proy_Intento1/data/data100/test100.json
  establishing parallel connection:
  host compute node: [4 cores] on b-aspire-f5

  Step 6: Clustering at 0.85 similarity across 26 samples
  [####################] 100%  concat/shuffle input  | 0:00:00  
  [####################] 100%  clustering across     | 0:00:02  
  [####################] 100%  building clusters     | 0:00:01  
  [####################] 100%  aligning clusters     | 0:00:11  
  [####################] 100%  database indels       | 0:00:00  
  [####################] 100%  indexing clusters     | 0:00:05  
  [####################] 100%  building database     | 0:00:00

# %%
# Resumen de los resultados del paso 6
ipyrad -p params-test100.txt -r

# %%
Summary stats of Assembly test100
------------------------------------------------
                   state  reads_raw  reads_passed_filter  clusters_total  \
100_ATX_1_S237001      6     100000                99515           38670   
100_ATX_2_S155001      6     100000                99514           39236   
100_ATX_3_S167001      6     100000                99503           39201   
100_ATX_4_S179001      6     100000                99518           39665   
100_ATX_5_S190001      6     100000                99535           39145   
100_ATX_6_S202001      6     100000                99484           39914   
100_ATX_7_S214001      6     100000                99493           38299   
100_ATX_8_S226001      6     100000                99563           38374   
100_ATX_9_S238001      6     100000                99527           39023   
100_PRE_1_S152001      6     100000                99628           31504   
100_PRE_2_S164001      6     100000                99506           39055   
100_PRE_3_S176001      6     100000                99514           38457   
100_PRE_5_S199001      6     100000                99612           24574   
100_PRE_6_S211001      6     100000                99638           25751   
100_PRE_7_S223001      6     100000                99486           37787   
100_PRE_8_S235001      6     100000                99344           25164   
100_PRE_9_S153001      6     100000                99602           25367   
100_QUE_1_S228001      6     100000                99517           37568   
100_QUE_2_S240001      6     100000                99592           39125   
100_QUE_3_S158001      6     100000                99570           38236   
100_QUE_4_S170001      6     100000                99533           38286   
100_QUE_5_S182001      6     100000                99476           38511   
100_QUE_6_S193001      6     100000                99493           38445   
100_QUE_7_S205001      6     100000                99487           38480   
100_QUE_8_S217001      6     100000                99532           38648   
100_QUE_9_S229001      6     100000                99542           37928   

                   clusters_hidepth  hetero_est  error_est  reads_consens  
100_ATX_1_S237001               992    0.032624   0.014288            489  
100_ATX_2_S155001              1036    0.031200   0.014542            546  
100_ATX_3_S167001               957    0.034570   0.012894            473  
100_ATX_4_S179001              1062    0.031465   0.013548            586  
100_ATX_5_S190001               989    0.035458   0.015471            474  
100_ATX_6_S202001              1036    0.031258   0.014061            560  
100_ATX_7_S214001              1018    0.034722   0.014058            489  
100_ATX_8_S226001              1274    0.025144   0.011142            805  
100_ATX_9_S238001               970    0.035310   0.013636            459  
100_PRE_1_S152001              1483    0.022728   0.006983           1069  
100_PRE_2_S164001               978    0.033174   0.014663            482  
100_PRE_3_S176001               964    0.033605   0.014555            479  
100_PRE_5_S199001              1410    0.020188   0.005705           1052  
100_PRE_6_S211001              1452    0.021020   0.007457           1071  
100_PRE_7_S223001              1022    0.035278   0.014910            489  
100_PRE_8_S235001              1478    0.019386   0.006110           1129  
100_PRE_9_S153001              1442    0.020811   0.005874           1107  
100_QUE_1_S228001              1016    0.037283   0.013706            510  
100_QUE_2_S240001              1008    0.033238   0.014962            501  
100_QUE_3_S158001              1023    0.034100   0.013835            524  
100_QUE_4_S170001              1000    0.034096   0.013755            500  
100_QUE_5_S182001              1074    0.033236   0.013355            555  
100_QUE_6_S193001              1032    0.033028   0.013900            536  
100_QUE_7_S205001               984    0.037636   0.013852            465  
100_QUE_8_S217001              1016    0.035304   0.014896            497  
100_QUE_9_S229001               951    0.038032   0.013541            459  


Full stats files
------------------------------------------------
step 1: ./test100_s1_demultiplex_stats.txt
step 2: ./test100_edits/s2_rawedit_stats.txt
step 3: ./test100_clust_0.85/s3_cluster_stats.txt
step 4: ./test100_clust_0.85/s4_joint_estimate.txt
step 5: ./test100_consens/s5_consens_stats.txt
step 6: ./test100_across/s6_cluster_stats.txt
step 7: None

# %%
# Correr paso 7
# Filtering and formatting output files
ipyrad -p params-test100.txt -s 7

# %%
 -------------------------------------------------------------
  ipyrad [v.0.7.23]
  Interactive assembly and analysis of RAD-seq data
 -------------------------------------------------------------
  loading Assembly: test100
  from saved path: ~/Escritorio/Bren_bioinf/Proy_Intento1/data/data100/test100.json
  establishing parallel connection:
  host compute node: [4 cores] on b-aspire-f5

  Step 7: Filter and write output files for 26 Samples
  [####################] 100%  filtering loci        | 0:00:07  
  [####################] 100%  building loci/stats   | 0:00:01  
  [####################] 100%  building vcf file     | 0:00:03  
  [####################] 100%  writing vcf file      | 0:00:00  
  [####################] 100%  building arrays       | 0:00:01  
  [####################] 100%  writing outfiles      | 0:00:00  
  Outfiles written to: ~/Escritorio/Bren_bioinf/Proy_Intento1/data/data100/test100_outfiles

# %%
# Resumen de los resultados del paso 7
ipyrad -p params-test100.txt -r

# %%
Summary stats of Assembly test100
------------------------------------------------
                   state  reads_raw  reads_passed_filter  clusters_total  \
100_ATX_1_S237001      6     100000                99515           38670   
100_ATX_2_S155001      6     100000                99514           39236   
